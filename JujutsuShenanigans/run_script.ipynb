# %%
import urllib.request
import ssl

ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

req = urllib.request.Request("https://maven.blamejared.com/foundry/veil/veil-fabric-1.21.1/3.1.2/veil-fabric-1.21.1-3.1.2.pom")
try:
    with urllib.request.urlopen(req, context=ctx) as response:
        print(response.read().decode('utf-8'))
except Exception as e:
    print(e)
# Out:
# Running cells with 'Python 3.12.3' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/workspaces/Minecraft/.venv/bin/python -m pip install ipykernel -U --user --force-reinstall'

# %%
# !python /workspaces/Minecraft/JujutsuShenanigans/delete_files.py

# %%
# Out:
# Running cells with 'Python 3.12.3' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/workspaces/Minecraft/.venv/bin/python -m pip install ipykernel -U --user --force-reinstall'
