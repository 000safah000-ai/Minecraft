# %%
import subprocess
import os

env = os.environ.copy()
env['JAVA_HOME'] = '/usr/local/sdkman/candidates/java/21.0.9-ms'
env['PATH'] = f"{env['JAVA_HOME']}/bin:{env['PATH']}"

result = subprocess.run(['./gradlew', 'build'], cwd='/workspaces/Minecraft/JujutsuShenanigans', env=env, capture_output=True, text=True)
print(result.stdout)
print(result.stderr)
